# %% [markdown]
# # Module 1
#
# Google Colab Fundamentals
#
# Author:
# Date:

# %%
print("Hello AI Engineering!")
# Out:
# Hello AI Engineering!

# %%
name = "AI Engineer"
year = 2026

print(name)
print(year)

# %%
x = 10
y = 20

print(x + y)

# %%
def greet(name):
    return f"Hello, {name}!"

print(greet("Ahmed"))

# %%
# !pip install requestsbbb

# %%
import requests

print(requests.__version__)

# %%
import os

print(os.listdir())

# %%
with open("hello.txt", "w") as file:
    file.write("Hello from Colab!")

# %%
name = "AI Engineer"

# %%
import requests

# %%
# !pip install requests

# %%
os.listdir()

# %%
print(username)
#NameError



username = "Ahmed"
print(username)

# %% [markdown]
# ## Refactoring

# %%
print("Hello Ahmed")
print("Hello Sara")
print("Hello Ali")

# %%
print("Hello Ahmed")
print("Hello Sara")
print("Hello Ali")
