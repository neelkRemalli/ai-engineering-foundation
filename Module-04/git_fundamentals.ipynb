# %%
# !git --version
# Out:
# git version 2.34.1

# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# sample_data

# %%
# !git init

# %%
# !git add .

# %%
# !git status

# %%
# !git commit -m "Inital commit"

# %%
# !git config --global user.email "aboneel1971@gmail.com"
# !git config --global user.name "neelkRemalli"

# %%
# !git remote add origin https://github.com/neelkRemalli/ai-engineering-foundation

# %%
# !git push -u origin main
#1git push -u origin master
