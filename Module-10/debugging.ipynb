# %%
# Syntax Error
# A mistake in Python syntax that prevents the program from running.
print("Hello"
# Out:
#   File "/tmp/ipykernel_3047/2743960588.py", line 2
#     print("Hello"
#                  ^
# SyntaxError: incomplete input

# %%
# Runtime Error
# An error that happens while the program is running.
number = 10
result = number /0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_3047/2854945984.py in <cell line: 0>()
#       1 # Runtime Error
#       2 number = 10
# ----> 3 result = number /0
#
# ZeroDivisionError: division by zero

# %%
# Name Error
# variable did no exist
print(username)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3047/119248832.py in <cell line: 0>()
#       1 # Name Error
# ----> 2 print(username)
#
# NameError: name 'username' is not defined

# %%
# Use print() for Debugging
price = 100
tax = 15

print(price)
print(tax)

total = price + tax

print(total)
# Out:
# 100
# 15
# 115

# %%
# Using try /except

try:
  number = 10 / 0
except ZeroDivisionError:
  print("Can not divide by zero")
# Out:
# Can not divide by zero

# %%
# Multiple Exceptions
try:
  number = int(input("Enter a number: "))
  result = 10 / number

except ValueError:
  print("Please enter a valid number")

except ZeroDivisionError:
  print("Division by zero is not allowed")

finally:
  print("Finished")
# Out:
# Enter a number: 0
# Division by zero is not allowed
# Finished

# %%
# Finally
try:
  print("working")

finally:
  print("Finished")
# Out:
# working
# Finished

# %%
# Raise
age = -5

if age < 0:
  raise ValueError("Age cna not be negative")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3047/2062276459.py in <cell line: 0>()
#       3
#       4 if age < 0:
# ----> 5   raise ValueError("Age cna not be negative")
#
# ValueError: Age cna not be negative

# %%
# Traceback
# Read from bottom to top

# Traceback (most recent call last): ()
#   File "main.py", line 5
# ZeroDivisionError: division by zero

# %%
# Refactoring
number = int(input())
result = 10 / number
print(result)
# Out:
# 9
# 1.1111111111111112

# %%
def divide(number):
  if number == 0:
    raise ValueError("Number can not be zero")

  return 10 / number

try:
  value = divide(2)
  print(value)
except ValueError as error:
  print(error)
# Out:
# 5.0
